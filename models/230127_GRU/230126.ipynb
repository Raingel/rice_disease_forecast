# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install tensorflow-addons
# !wget -O taipei_sans_tc_beta.ttf https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_&export=download
import matplotlib
# 新增字體
matplotlib.font_manager.fontManager.addfont('taipei_sans_tc_beta.ttf')
# 將 font-family 設為 Taipei Sans TC Beta
# 設定完後，之後的圖表都可以顯示中文了
matplotlib.rc('font', family='Taipei Sans TC Beta')
# Out:
# Mounted at /content/drive
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting tensorflow-addons
#   Downloading tensorflow_addons-0.19.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow-addons) (21.3)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow-addons) (2.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging->tensorflow-addons) (3.0.9)
# Installing collected packages: tensorflow-addons
# Successfully installed tensorflow-addons-0.19.0
# --2023-01-26 11:38:09--  https://drive.google.com/uc?id=1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_
# Resolving drive.google.com (drive.google.com)... 209.85.145.102, 209.85.145.138, 209.85.145.101, ...
# Connecting to drive.google.com (drive.google.com)|209.85.145.102|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/89mmjd7jo9ka2t6shh42aopdmmhiu51p/1674733050000/02847987870453524430/*/1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_?uuid=384a8dc9-ed07-4673-adeb-67a63483a6ba [following]
# Warning: wildcards not supported in HTTP.
# --2023-01-26 11:38:10--  https://doc-0k-9o-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/89mmjd7jo9ka2t6shh42aopdmmhiu51p/1674733050000/02847987870453524430/*/1eGAsTN1HBpJAkeVM57_C7ccp7hbgSz3_?uuid=384a8dc9-ed07-4673-adeb-67a63483a6ba
# Resolving doc-0k-9o-docs.googleusercontent.com (doc-0k-9o-docs.googleusercontent.com)... 74.125.126.132, 2607:f8b0:4001:c1d::84
# Connecting to doc-0k-9o-docs.googleusercontent.com (doc-0k-9o-docs.googleusercontent.com)|74.125.126.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 20659344 (20M) [application/x-font-ttf]
# Saving to: ‘taipei_sans_tc_beta.ttf’
#
# taipei_sans_tc_beta 100%[===================>]  19.70M  27.8MB/s    in 0.7s
#
# 2023-01-26 11:38:10 (27.8 MB/s) - ‘taipei_sans_tc_beta.ttf’ saved [20659344/20659344]

# %%
import numpy as np
from matplotlib import pyplot as plt
import tensorflow_addons as tfa
import tensorflow as tf
import numpy as np
import os
from random import random
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.layers import Input, Dense, GRU, Bidirectional, LSTM
from tensorflow.keras import backend as K
from sklearn.utils import shuffle
from math import sqrt
ROOT = "./"
ROOT = "/content/drive/MyDrive/Colab_2022/blast_forecast/新模型221208/"
radam = tfa.optimizers.RectifiedAdam()
ranger = tfa.optimizers.Lookahead(radam, sync_period=6, slow_step_size=0.5)
ranger2 = tfa.optimizers.Lookahead(tfa.optimizers.RectifiedAdam(learning_rate=0.001))
#Show tensorflow version
print(tf.__version__)
# Out:
# 2.9.2

# %%
#Custom function 
def weighted_binary_crossentropy(zero_weight, one_weight):
    def weighted_binary_crossentropy(y_true, y_pred):
        b_ce = K.binary_crossentropy(y_true, y_pred)
        #weighted calc
        weight_vector = y_true * zero_weight + (1.0 - y_true) * one_weight
        weighted_b_ce = weight_vector * b_ce
        return K.mean(weighted_b_ce)
    return weighted_binary_crossentropy
def confusion_matrix_calculator(gt_y, prediction):
    TP = ((gt_y + (prediction>0.5))==2).sum()
    TN = ((gt_y + (prediction>0.5))==0).sum()
    FP = ((gt_y - (prediction>0.5))==-1).sum()
    FN = ((gt_y - (prediction>0.5))==1).sum()
    MCC = (TP*TN - FP*FN) / sqrt((TP+FP)*(TP+FN)*(TN+FP)*(TN+FN))
    return {'TP': TP, 'TN': TN, 'FP': FP, 'FN': FN, 'MCC': MCC, 'ACC': (TP+TN)/(TP+TN+FP+FN)}

# %%
#Load x,y
x = np.load(ROOT+'/2_packed_array/x.npy', allow_pickle=True)
y = np.load(ROOT+'/2_packed_array/y.npy', allow_pickle=True)
#drop first feature (date)
x = x[:, :, 1:]

with open(ROOT+"/2_packed_array/col.txt", 'r', encoding='utf-8-sig') as f:
    col = eval(f.read())
col = col[1:]
#normalization
for feature in range(x.shape[2]):
    #x[:, :, feature] = (x[:, :, feature] - np.mean(x[:, :, feature])) / np.std(x[:, :, feature])
    #min-max normalization
    print(col[feature],  np.min(x[:, :, feature]), (np.max(x[:, :, feature]) - np.min(x[:, :, feature])))
    x[:, :, feature] = (x[:, :, feature] - np.min(x[:, :, feature])) / (np.max(x[:, :, feature]) - np.min(x[:, :, feature])+0.001)
# Out:
# temperature_2m_mean 9.9625 21.016666666666666
# temperature_2m_min 6.9 21.799999999999997
# relativehumidity_2m_max 57.0 43.0
# relativehumidity_2m_mean 44.916666666666664 54.00000000000001
# relativehumidity_2m_min 34.0 64.0
# precipitation_mean 0.0 6.2749999999999995
# cloudcover_mean 0.0 100.0
# direct_radiation_mean 0.0 282.2083333333333
# Wu_mean -45.73243936825596 66.01164576691622
# Wv_mean -40.00775993815649 63.11120843486081

# %%
#Visualize features
plt.figure(figsize=(20, 10))
#Set chinese font 
plt.rcParams['font.sans-serif'] = ['Yu Gothic']
#visualize first 5 samples
for sample in range(10,400,40):
    for feature in range(x.shape[2]):
        plt.subplot(6, 6, feature+1)
        plt.plot(x[sample, :, feature])
        plt.title(col[feature])
# Out:
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)
# <ipython-input-5-c3ad6db244b0>:8: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(6, 6, feature+1)

# %%
#train by each feature
def go_train(train_x, train_y,  val_x, val_y, model_path=ROOT+"3_model", name_during_training = "5566",neuron_num=256, dropout = 0.2, verbose=0):
    try:
        os.remove(model_path)
    except:
        pass
    unique_id = int(random()*100000) # quite unlike 
    weather_input = Input(shape=(train_x.shape[1], train_x.shape[2])) 
    L1_1 = Bidirectional(GRU(neuron_num, dropout=dropout, name=f"GRU{unique_id}"), name=f"Bi{unique_id}")(weather_input)
    output = Dense(1, 
            activation='sigmoid',
            )(L1_1)
    model = Model(inputs=weather_input, 
                outputs=output,
                name = f"n{unique_id}" #Should be set to make every run separated
                )
    model.summary()
    early_stop = tf.keras.callbacks.EarlyStopping(
                                                  monitor='val_loss',
                                                  mode = 'min', 
                                                  #monitor='val_accuracy',
                                                  #mode = 'max', 
                                                  patience=300
                                                  )
    model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
                                filepath=model_path,
                                save_weights_only=False,
                                monitor='val_loss',
                                mode='min',
                                #monitor='val_accuracy',
                                #mode='max',
                                verbose=verbose,
                                save_best_only=True
                                )
    #Calculate weight
    class_count = np.unique(train_y, return_counts=True)[1]
    total = class_count[0] + class_count[1]
    neg =  class_count[0]
    pos = class_count[1]
    weight_for_0 = (1 / neg) * (total / 2.0)
    weight_for_1 = (1 / pos) * (total / 2.0)
    class_weight = {0: weight_for_0, 1: weight_for_1}
    print(class_weight)
    model.compile(
        #loss=customLoss, 
        #loss = weighted_binary_crossentropy(weight_for_0,weight_for_1),
        #loss='mse',
        loss="binary_crossentropy",
        #optimizer=Nadam(),
        #optimizer = ranger,
        #optimizer = tf.keras.optimizers.Adam(),
        optimizer = ranger2,
        metrics=['accuracy'],
        #optimizer=SGD()
        )
    #train_x, train_y = shuffle(train_x, train_y) 
    model.fit(train_x,
            train_y,
            epochs=5000,
            batch_size= int(len(train_x)/2),
            validation_data=(val_x, val_y), 
            verbose=verbose, 
            shuffle=True,
            class_weight=class_weight,
            callbacks=[
            model_checkpoint_callback,
            early_stop,
            ]
            )
    return model

# %%
#Selected features
selected_features = [0,2,5,8,9]
ds = (-24,-4)
selected_features_name = [f"*{f}"  if col.index(f) in selected_features else f" {f}" for f in col]
print("\n".join(selected_features_name))
# Out:
# *temperature_2m_mean
#  temperature_2m_min
# *relativehumidity_2m_max
#  relativehumidity_2m_mean
#  relativehumidity_2m_min
# *precipitation_mean
#  cloudcover_mean
#  direct_radiation_mean
# *Wu_mean
# *Wv_mean

# %%
x_aug = []
y_aug = []
for x1, y1 in zip(x,y):
    for shift in range(-1,2):
        x_aug.append(x1[ds[0]+shift:ds[1]+shift,selected_features])
        y_aug.append(y1)

# %%
#shuffle data
X = np.array(x_aug)
Y = np.array(y_aug)
X, Y = shuffle(X, Y)
#split
train_x = X[:int(len(X)*0.8)]
train_y = Y[:int(len(Y)*0.8)]
val_x = X[int(len(X)*0.8):]
val_y = Y[int(len(Y)*0.8):]
#Print shape
print("train_x shape: ", train_x.shape, "train_y shape: ", train_y.shape, "val_x shape: ", val_x.shape, "val_y shape: ", val_y.shape)
#y class count
print("train_y class count: ", np.unique(train_y, return_counts=True))
# Out:
# train_x shape:  (1514, 20, 5) train_y shape:  (1514,) val_x shape:  (379, 20, 5) val_y shape:  (379,)
# train_y class count:  (array([0, 1], dtype=int32), array([952, 562]))

# %%
MODEL_PATH = ROOT+"3_model/"+"230126.h5"
name_during_training = "230126"
#tf.keras.backend.clear_session()
model = go_train(train_x, train_y, val_x, val_y, model_path=MODEL_PATH,neuron_num=36,dropout = 0.05, verbose=1)
predictor = load_model(MODEL_PATH)
pre = predictor.predict(val_x)
pre = pre.reshape(pre.shape[0])
cf_matrix = confusion_matrix_calculator(val_y.astype(float), pre)
print(cf_matrix)
print(f"Features: {selected_features}, {selected_features_name}, {ds}")
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
# Epoch 1023/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.3779 - accuracy: 0.8263
# Epoch 1023: val_loss did not improve from 0.38074
# 2/2 [==============================] - 0s 183ms/step - loss: 0.3779 - accuracy: 0.8263 - val_loss: 0.4121 - val_accuracy: 0.8364
# Epoch 1024/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.3808 - accuracy: 0.8197
# Epoch 1024: val_loss did not improve from 0.38074
# 2/2 [==============================] - 0s 179ms/step - loss: 0.3808 - accuracy: 0.8197 - val_loss: 0.3948 - val_accuracy: 0.8496
# Epoch 1025/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.3680 - accuracy: 0.8309
# Epoch 1025: val_loss did not improve from 0.38074
# 2/2 [==============================] - 0s 167ms/step - loss: 0.3680 - accuracy: 0.8309 - val_loss: 0.4132 - val_accuracy: 0.8496
# Epoch 1026/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.3893 - accuracy: 0.8012
# Epoch 1026: val_loss did not improve from 0.38074
# 2/2 [==============================] - 0s 165ms/step - loss: 0.3893 - accuracy: 0.8012 - val_loss: 0.4114 - val_accuracy: 0.8311
# Epoch 1027/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.3700 - accuracy: 0.8236
# Epoch 1027: val_loss did not improve from 0.38074
# 2/2 [==============================] - 0s 183ms/step - loss: 0.3700 - accuracy: 0.8236 - val_loss: 0.4090 - val_accuracy: 0.8522
# Epoch 1028/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.3753 - accuracy: 0.8342
# Epoch 1028: val_loss did not improve from 0.38074
# 2/2 [==============================] - 0s 170ms/step - loss: 0.3753 - accuracy: 0.8342 - val_loss: 0.4087 - val_accuracy: 0.8364
# Epoch 1029/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.3717 - accuracy: 0.8243
# Epoch 1029: val_loss did not improve from 0.38074
# 2/2 [==============================] - 0s 183ms/step - loss: 0.3717 - accuracy: 0.8243 - val_loss: 0.4161 - val_accuracy: 0.8338
# Epoch 1030/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.3770 - accuracy: 0.8269
# Epoch 1030: val_loss did not improve from 0.38074
# 2/2 [==============================] - 0s 193ms/step - loss: 0.3770 - accuracy: 0.8269 - val_loss: 0.3896 - val_accuracy: 0.8496
# Epoch 1031/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.3799 - accuracy: 0.8177
# Epoch 1031: val_loss did not improve from 0.38074
# 2/2 [==============================] - 0s 183ms/step - loss: 0.3799 - accuracy: 0.8177 - val_loss: 0.4061 - val_accuracy: 0.8417
# Epoch 1032/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.3685 - accuracy: 0.8303
# Epoch 1032: val_loss did not improve from 0.38074
# 2/2 [==============================] - 0s 178ms/step - loss: 0.3685 - accuracy: 0.8303 - val_loss: 0.4105 - val_accuracy: 0.8417
# Epoch 1033/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.3711 - accuracy: 0.8164
# Epoch 1033: val_loss did not improve from 0.38074
# 2/2 [==============================] - 0s 191ms/step - loss: 0.3711 - accuracy: 0.8164 - val_loss: 0.3850 - val_accuracy: 0.8549
# Epoch 1034/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.3888 - accuracy: 0.8137
# Epoch 1034: val_loss did not improve from 0.38074
# 2/2 [==============================] - 0s 175ms/step - loss: 0.3888 - accuracy: 0.8137 - val_loss: 0.4200 - val_accuracy: 0.8443
# Epoch 1035/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.
val_loss did not improve from 0.32978
# 2/2 [==============================] - 0s 194ms/step - loss: 0.2856 - accuracy: 0.8705 - val_loss: 0.4024 - val_accuracy: 0.8338
# Epoch 2259/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.2655 - accuracy: 0.8884
# Epoch 2259: val_loss did not improve from 0.32978
# 2/2 [==============================] - 0s 175ms/step - loss: 0.2655 - accuracy: 0.8884 - val_loss: 0.4141 - val_accuracy: 0.8338
# Epoch 2260/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.2797 - accuracy: 0.8811
# Epoch 2260: val_loss did not improve from 0.32978
# 2/2 [==============================] - 0s 194ms/step - loss: 0.2797 - accuracy: 0.8811 - val_loss: 0.3460 - val_accuracy: 0.8522
# Epoch 2261/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.2834 - accuracy: 0.8692
# Epoch 2261: val_loss did not improve from 0.32978
# 2/2 [==============================] - 0s 186ms/step - loss: 0.2834 - accuracy: 0.8692 - val_loss: 0.4448 - val_accuracy: 0.8206
# Epoch 2262/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.2944 - accuracy: 0.8745
# Epoch 2262: val_loss did not improve from 0.32978
# 2/2 [==============================] - 0s 192ms/step - loss: 0.2944 - accuracy: 0.8745 - val_loss: 0.4030 - val_accuracy: 0.8364
# Epoch 2263/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.2729 - accuracy: 0.8864
# Epoch 2263: val_loss did not improve from 0.32978
# 2/2 [==============================] - 0s 209ms/step - loss: 0.2729 - accuracy: 0.8864 - val_loss: 0.3469 - val_accuracy: 0.8549
# Epoch 2264/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.2808 - accuracy: 0.8725
# Epoch 2264: val_loss did not improve from 0.32978
# 2/2 [==============================] - 0s 178ms/step - loss: 0.2808 - accuracy: 0.8725 - val_loss: 0.4230 - val_accuracy: 0.8364
# Epoch 2265/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.2856 - accuracy: 0.8752
# Epoch 2265: val_loss did not improve from 0.32978
# 2/2 [==============================] - 0s 190ms/step - loss: 0.2856 - accuracy: 0.8752 - val_loss: 0.3987 - val_accuracy: 0.8364
# Epoch 2266/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.2746 - accuracy: 0.8897
# Epoch 2266: val_loss did not improve from 0.32978
# 2/2 [==============================] - 0s 189ms/step - loss: 0.2746 - accuracy: 0.8897 - val_loss: 0.3759 - val_accuracy: 0.8417
# Epoch 2267/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.2792 - accuracy: 0.8851
# Epoch 2267: val_loss did not improve from 0.32978
# 2/2 [==============================] - 0s 184ms/step - loss: 0.2792 - accuracy: 0.8851 - val_loss: 0.4055 - val_accuracy: 0.8364
# Epoch 2268/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.2844 - accuracy: 0.8699
# Epoch 2268: val_loss did not improve from 0.32978
# 2/2 [==============================] - 0s 167ms/step - loss: 0.2844 - accuracy: 0.8699 - val_loss: 0.3987 - val_accuracy: 0.8338
# Epoch 2269/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.2885 - accuracy: 0.8692
# Epoch 2269: val_loss did not improve from 0.32978
# 2/2 [==============================] - 0s 178ms/step - loss: 0.2885 - accuracy: 0.8692 - val_loss: 0.3907 - val_accuracy: 0.8338
# Epoch 2270/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.2789 - accuracy: 0.8725
# Epoch 2270: val_loss did not improve from 0.32978
# 2/2 [==============================] - 0s 218ms/step - loss: 0.2789 - accuracy: 0.8725 - val_loss: 0.3671 - val_accuracy: 0.8443
# Epoch 2271/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.2622 - accuracy: 0.8956
# Epoch 2271: val_loss did not improve from 0.32978
# 2/2 [==============================] - 0s 175ms/step - loss: 0.2622 - accuracy: 0.8956 - val_loss: 0.4223 - val_accuracy: 0.8285
# Epoch 2272/5000
# 2/2 [==============================] - ETA: 0s - loss: 0.2739 - accuracy: 0.8851
# Epoch 2272: val_loss did not improve from 0.32978
# 2/2 [==============================] - 0s 188ms/step - loss: 0.2739 - accuracy: 0.8851 - val_loss: 0.4168 - val_accuracy: 0.8338
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.
# 12/12 [==============================] - 1s 6ms/step
# {'TP': 83, 'TN': 241, 'FP': 22, 'FN': 33, 'MCC': 0.6506727928262396, 'ACC': 0.8548812664907651}
# Features: [0, 2, 5, 8, 9], ['*temperature_2m_mean', ' temperature_2m_min', '*relativehumidity_2m_max', ' relativehumidity_2m_mean', ' relativehumidity_2m_min', '*precipitation_mean', ' cloudcover_mean', ' direct_radiation_mean', '*Wu_mean', '*Wv_mean'], (-24, -4)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(10,6))
ax.plot(model.history.history['loss'],label = "loss")
ax.plot(model.history.history['val_loss'], label="val_loss")
ax.plot(model.history.history['accuracy'],label = "accuracy")
ax.plot(model.history.history['val_accuracy'], label="val_accuracy")
ax.legend()
